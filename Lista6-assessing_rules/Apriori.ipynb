# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __ixor__(self, value, /)
#  |      Return self^=value.
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(...)
#  |      S.__sizeof__() -> size of S in memory, in bytes
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  add(...)
#  |      Add an element to a set.
#  |
#  |      This has no effect if the element is already present.
#  |
#  |  clear(...)
#  |      Remove all elements from this set.
#  |
#  |  copy(...)
#  |      Return a shallow copy of a set.
#  |
#  |  difference(...)
#  |      Return the difference of two or more sets as a new set.
#  |
#  |      (i.e. all elements that are in this set but not the others.)
#  |
#  |  difference_update(...)
#  |      Remove all elements of another set from this set.
#  |
#  |  discard(...)
#  |      Remove an element from a set if it is a member.
#  |
#  |      If the element is not a member, do nothing.
#  |
#  |  intersection(...)
#  |      Return the intersection of two sets as a new set.
#  |
#  |      (i.e. all elements that are in both sets.)
#  |
#  |  intersection_update(...)
#  |      Update a set with the intersection of itself and another.
#  |
#  |  isdisjoint(...)
#  |      Return True if two sets have a null intersection.
#  |
#  |  issubset(...)
#  |      Report whether another set contains this set.
#  |
#  |  issuperset(...)
#  |      Report whether this set contains another set.
#  |
#  |  pop(...)
#  |      Remove and return an arbitrary set element.
#  |      Raises KeyError if the set is empty.
#  |
#  |  remove(...)
#  |      Remove an element from a set; it must be a member.
#  |
#  |      If the element is not a member, raise a KeyError.
#  |
#  |  symmetric_difference(...)
#  |      Return the symmetric difference of two sets as a new set.
#  |
#  |      (i.e. all elements that are in exactly one of the sets.)
#  |
#  |  symmetric_difference_update(...)
#  |      Update a set with the symmetric difference of itself and another.
#  |
#  |  union(...)
#  |      Return the union of sets as a new set.
#  |
#  |      (i.e. all elements that are in either set.)
#  |
#  |  update(...)
#  |      Update a set with the union of itself and others.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
class Apriori:
    def __init__(self, min_supp, min_conf, products, transactions):
        self.min_supp = min_supp
        self.min_conf = min_conf
        self.products = products
        self.transactions = transactions
        self.trans_len = len(transactions)

    def occurence(self, p):
        occ = 0
        for t in self.transactions:
            occ += int(p in t)
        return occ/self.trans_len

    def supp(self, s):
        occ = 0
        for t in self.transactions:
            occ += int(s.issubset(t))
        return occ/self.trans_len
    
    def confidance(self, rule):
        return self.supp(rule[0] | rule[1])/self.supp(rule[0])
    
    def makeFrequentSets(self):
        F = list()
        F.append(frozenset({frozenset({p}) for p in self.products  if self.occurence(p) >= self.min_supp}))
        i = 1
#         print(F[0])
        while len(F[i-1]) > 0:
            C = { frozenset(L1 | L2) for L1 in F[i-1] for L2 in F[i-1] if len(L1 | L2) == i+1 and self.supp(L1 | L2) >= self.min_supp}
#             print(i,C)
            F.append(C)
            i += 1
        self.frequent_sets = list(itertools.chain.from_iterable(F))
        return self.frequent_sets
    
    def makeAssesRules(self, computeOther=True):
        R = list()
        R.append({ (s,frozenset()) for s in self.frequent_sets})
        i = 1
        while len(R[i-1]) > 0:
            C = {(X[0] - {pre},X[1] | {pre}) for X in R[i-1] for pre in X[0] if self.confidance((X[0] - {pre},X[1] | {pre})) >= self.min_conf }
#             print(C)
            R.append(C)
            i += 1
        self.asses_rules = list(itertools.chain.from_iterable(R))
        
        if computeOther:
            self.rulesLift = {}
            self.rulesLeverage = {}
            for r in self.asses_rules:
                self.rulesLift[r] = self.lift(r)
                self.rulesLeverage[r] = self.leverage(r)
        return self.asses_rules
        
    def lift(self, rule):
        return self.confidance(rule)/self.supp(rule[1])
    
    def liftFilter(self, val):
        return [r for r in self.asses_rules if self.lift(r) >= val]
    
    def leverage(self, rule):
        return self.supp(rule[0] | rule[1]) - self.supp(rule[0]) * self.supp(rule[1])
    
    def leverageFilter(self, val):
        return [r for r in self.asses_rules if self.leverage(r) >= val]

# %%
a = Apriori(0.5,0.7,[1,2,3], [{1,2}, {2,3}, {1,2}])
a.makeFrequentSets()
a.frequent_sets
# Out:
# [frozenset({2}), frozenset({1}), frozenset({1, 2})]

# %%
a.makeAssesRules()
a.asses_rules
# Out:
# [(frozenset({1}), frozenset()),
#  (frozenset({2}), frozenset()),
#  (frozenset({1, 2}), frozenset()),
#  (frozenset({1}), frozenset({2})),
#  (frozenset(), frozenset({2}))]

# %%
products = np.arange(10)
transactions = np.array([set(products[np.random.randint(0,10,np.random.randint(0,10))]) for i in range(100)])

# %%
a = Apriori(0.1, 0.2, products, transactions)

# %%
a.makeFrequentSets()
# Out:
# [frozenset({8}),
#  frozenset({4}),
#  frozenset({9}),
#  frozenset({7}),
#  frozenset({5}),
#  frozenset({3}),
#  frozenset({0}),
#  frozenset({6}),
#  frozenset({1}),
#  frozenset({2}),
#  frozenset({5, 7}),
#  frozenset({3, 7}),
#  frozenset({1, 9}),
#  frozenset({3, 6}),
#  frozenset({5, 6}),
#  frozenset({1, 5}),
#  frozenset({2, 6}),
#  frozenset({2, 8}),
#  frozenset({6, 9}),
#  frozenset({1, 2}),
#  frozenset({8, 9}),
#  frozenset({0, 9}),
#  frozenset({0, 6}),
#  frozenset({0, 5}),
#  frozenset({3, 5}),
#  frozenset({3, 9}),
#  frozenset({3, 4}),
#  frozenset({5, 9}),
#  frozenset({2, 3}),
#  frozenset({0, 2}),
#  frozenset({2, 5}),
#  frozenset({1, 6}),
#  frozenset({0, 1}),
#  frozenset({4, 9}),
#  frozenset({0, 4}),
#  frozenset({5, 8}),
#  frozenset({1, 7}),
#  frozenset({3, 8}),
#  frozenset({0, 8}),
#  frozenset({1, 3}),
#  frozenset({0, 3}),
#  frozenset({2, 7}),
#  frozenset({2, 4}),
#  frozenset({2, 9}),
#  frozenset({1, 8}),
#  frozenset({0, 7}),
#  frozenset({4, 6}),
#  frozenset({6, 8}),
#  frozenset({7, 9}),
#  frozenset({1, 3, 5}),
#  frozenset({1, 2, 8}),
#  frozenset({3, 6, 8}),
#  frozenset({0, 1, 3}),
#  frozenset({0, 6, 9}),
#  frozenset({1, 3, 6}),
#  frozenset({1, 2, 5}),
#  frozenset({1, 3, 8}),
#  frozenset({2, 3, 8}),
#  frozenset({1, 2, 3}),
#  frozenset({1, 3, 9})]

# %%
a.makeAssesRules()
a.leverageFilter(0.05)
# Out:
# [(frozenset({2, 3}), frozenset({8})),
#  (frozenset({3}), frozenset({2})),
#  (frozenset({6}), frozenset({9})),
#  (frozenset({1}), frozenset({5})),
#  (frozenset({8}), frozenset({9})),
#  (frozenset({3, 8}), frozenset({2})),
#  (frozenset({9}), frozenset({8})),
#  (frozenset({2}), frozenset({8})),
#  (frozenset({3, 5}), frozenset({1})),
#  (frozenset({9}), frozenset({6})),
#  (frozenset({8}), frozenset({3})),
#  (frozenset({3}), frozenset({8})),
#  (frozenset({2}), frozenset({3})),
#  (frozenset({8}), frozenset({2})),
#  (frozenset({3, 6}), frozenset({8})),
#  (frozenset({5}), frozenset({1})),
#  (frozenset({8}), frozenset({3, 6})),
#  (frozenset({2}), frozenset({3, 8})),
#  (frozenset({1}), frozenset({3, 5})),
#  (frozenset({8}), frozenset({2, 3}))]

# %%
allTransactions = [set([int(id.replace(',', '')) for id in line.split()][1:]) for line in open('/home/dominik/Dokumenty/Studia/Data-mining/Lista6-assiessing_rules/apriori/1000/1000-out1.csv')]

# data = pd.read_csv('/home/dominik/Dokumenty/Studia/Data-mining/Lista6-assiessing_rules/apriori/1000/1000-out1.csv', header=None)

# %%
allTransactions
# Out:
# [{7, 15, 44, 49},
#  {1, 19},
#  {1, 19},
#  {3, 4, 15, 18, 35, 44},
#  {2, 4, 7, 9, 23},
#  {14, 21, 44},
#  {4, 12, 31, 36, 44, 48},
#  {15, 27, 28},
#  {2, 28},
#  {3, 18, 35},
#  {23, 24, 40, 41, 43},
#  {20, 43, 48},
#  {49},
#  {1, 19, 26},
#  {5, 22, 39},
#  {16, 32, 45},
#  {4, 6, 9, 10, 16, 22},
#  {1, 19, 23},
#  {7, 11, 37, 45},
#  {3, 18, 32, 35},
#  {1, 8, 19, 47},
#  {34, 39, 44},
#  {13, 19},
#  {4, 9, 38},
#  {7, 22, 48},
#  {7, 11, 14},
#  {23, 24, 40, 41, 43},
#  {9, 14},
#  {0, 2, 42},
#  {13, 35},
#  {23},
#  {8, 21, 25, 38},
#  {4, 46},
#  {23, 24, 40, 41, 43},
#  {4, 17, 29, 47},
#  {12, 31, 36},
#  {14, 22, 26, 37, 44},
#  {0, 16, 30, 32, 45, 47},
#  {12, 31, 36},
#  {16, 32, 41, 45},
#  {16, 33, 42},
#  {12, 13, 31, 35, 36, 41, 44},
#  {6, 9, 19, 24, 44},
#  {23, 24, 40, 41, 43},
#  {5, 12, 31, 36, 48},
#  {0, 2, 20, 44, 46},
#  {3, 18, 35},
#  {4, 12, 14, 19, 32, 48},
#  {41},
#  {0, 14, 44},
#  {1, 10, 13, 19, 25, 26, 33, 39},
#  {7, 15, 16},
#  {4, 29, 46},
#  {14, 20, 40, 43},
#  {7, 38},
#  {3, 18, 45, 47},
#  {19, 29, 43},
#  {9, 16},
#  {0, 20, 42},
#  {5, 10, 32, 33, 39, 44},
#  {27, 28},
#  {5, 22, 25, 29, 37, 43},
#  {19},
#  {4, 16, 34},
#  {9, 17, 44, 45},
#  {7, 15, 29},
#  {7, 11, 27, 37, 39, 45, 49},
#  {12, 31, 36, 48},
#  {34, 49},
#  {31},
#  {25, 33, 42, 45},
#  {16, 27, 32, 45},
#  {25, 41},
#  {6, 9, 15, 24, 25, 40, 45},
#  {7, 8, 9, 11, 29, 37, 45},
#  {21, 36},
#  {5, 7, 14, 17, 22},
#  {38, 40},
#  {2, 7, 15, 22, 25, 33, 41},
#  {27, 28},
#  {16, 32, 45},
#  {8, 18, 28},
#  {13},
#  {41},
#  {27, 28, 38, 48},
#  {3, 18, 35},
#  {16, 20, 32, 36},
#  {16, 32, 45},
#  {4, 9},
#  {22, 31, 39},
#  {0, 2, 46},
#  {34},
#  {0, 2, 46},
#  {0},
#  {3, 6, 13},
#  {3, 29, 44},
#  {9, 27, 28, 45},
#  {2, 10, 22, 31, 33, 46},
#  {2, 6, 22, 32},
#  {0, 4, 9, 30, 33},
#  {3, 18, 35},
#  {15, 34, 47}]

# %%
products = list(range(100))

# %%
a = Apriori(0.01,0.07,products, allTransactions)

# %%
a.makeFrequentSets()
# Out:
# [frozenset({49}),
#  frozenset({38}),
#  frozenset({21}),
#  frozenset({19}),
#  frozenset({33}),
#  frozenset({22}),
#  frozenset({44}),
#  frozenset({5}),
#  frozenset({3}),
#  frozenset({28}),
#  frozenset({48}),
#  frozenset({29}),
#  frozenset({41}),
#  frozenset({30}),
#  frozenset({39}),
#  frozenset({20}),
#  frozenset({42}),
#  frozenset({32}),
#  frozenset({13}),
#  frozenset({11}),
#  frozenset({14}),
#  frozenset({23}),
#  frozenset({4}),
#  frozenset({34}),
#  frozenset({17}),
#  frozenset({6}),
#  frozenset({47}),
#  frozenset({18}),
#  frozenset({40}),
#  frozenset({1}),
#  frozenset({31}),
#  frozenset({12}),
#  frozenset({24}),
#  frozenset({25}),
#  frozenset({26}),
#  frozenset({16}),
#  frozenset({9}),
#  frozenset({7}),
#  frozenset({10}),
#  frozenset({0}),
#  frozenset({2}),
#  frozenset({37}),
#  frozenset({35}),
#  frozenset({15}),
#  frozenset({8}),
#  frozenset({45}),
#  frozenset({43}),
#  frozenset({46}),
#  frozenset({36}),
#  frozenset({27}),
#  frozenset({31, 48}),
#  frozenset({2, 46}),
#  frozenset({32, 45}),
#  frozenset({18, 35}),
#  frozenset({7, 15}),
#  frozenset({37, 45}),
#  frozenset({9, 13}),
#  frozenset({7, 11}),
#  frozenset({24, 43}),
#  frozenset({24, 40}),
#  frozenset({12, 31}),
#  frozenset({24, 41}),
#  frozenset({7, 37}),
#  frozenset({23, 33}),
#  frozenset({14, 22}),
#  frozenset({9, 45}),
#  frozenset({17, 47}),
#  frozenset({16, 32}),
#  frozenset({33, 42}),
#  frozenset({5, 14}),
#  frozenset({27, 28}),
#  frozenset({12, 48}),
#  frozenset({11, 37}),
#  frozenset({0, 2}),
#  frozenset({23, 42}),
#  frozenset({5, 22}),
#  frozenset({36, 48}),
#  frozenset({5, 42}),
#  frozenset({3, 35}),
#  frozenset({31, 36}),
#  frozenset({4, 9}),
#  frozenset({7, 49}),
#  frozenset({1, 19}),
#  frozenset({7, 45}),
#  frozenset({23, 41}),
#  frozenset({40, 41}),
#  frozenset({16, 45}),
#  frozenset({5, 31}),
#  frozenset({11, 45}),
#  frozenset({40, 43}),
#  frozenset({23, 40}),
#  frozenset({3, 18}),
#  frozenset({41, 43}),
#  frozenset({15, 49}),
#  frozenset({29, 47}),
#  frozenset({23, 24}),
#  frozenset({17, 29}),
#  frozenset({14, 44}),
#  frozenset({12, 36}),
#  frozenset({0, 46}),
#  frozenset({23, 43}),
#  frozenset({16, 32, 45}),
#  frozenset({23, 24, 41}),
#  frozenset({7, 15, 49}),
#  frozenset({24, 41, 43}),
#  frozenset({24, 40, 41}),
#  frozenset({12, 36, 48}),
#  frozenset({0, 2, 46}),
#  frozenset({7, 11, 45}),
#  frozenset({24, 40, 43}),
#  frozenset({12, 31, 48}),
#  frozenset({23, 24, 40}),
#  frozenset({23, 24, 43}),
#  frozenset({7, 11, 37}),
#  frozenset({11, 37, 45}),
#  frozenset({23, 40, 43}),
#  frozenset({17, 29, 47}),
#  frozenset({40, 41, 43}),
#  frozenset({23, 41, 43}),
#  frozenset({31, 36, 48}),
#  frozenset({3, 18, 35}),
#  frozenset({7, 37, 45}),
#  frozenset({23, 40, 41}),
#  frozenset({12, 31, 36}),
#  frozenset({23, 24, 40, 41}),
#  frozenset({23, 24, 40, 43}),
#  frozenset({24, 40, 41, 43}),
#  frozenset({23, 24, 41, 43}),
#  frozenset({12, 31, 36, 48}),
#  frozenset({7, 11, 37, 45}),
#  frozenset({23, 40, 41, 43}),
#  frozenset({23, 24, 40, 41, 43})]

# %%
a.makeAssesRules()
# Out:
# [(frozenset({5}), frozenset()),
#  (frozenset({48}), frozenset()),
#  (frozenset({29}), frozenset()),
#  (frozenset({3, 18, 35}), frozenset()),
#  (frozenset({30}), frozenset()),
#  (frozenset({27}), frozenset()),
#  (frozenset({2, 46}), frozenset()),
#  (frozenset({27, 28}), frozenset()),
#  (frozenset({33}), frozenset()),
#  (frozenset({12}), frozenset()),
#  (frozenset({23, 43}), frozenset()),
#  (frozenset({3, 35}), frozenset()),
#  (frozenset({17, 47}), frozenset()),
#  (frozenset({24, 41}), frozenset()),
#  (frozenset({8}), frozenset()),
#  (frozenset({16, 45}), frozenset()),
#  (frozenset({45}), frozenset()),
#  (frozenset({23, 40}), frozenset()),
#  (frozenset({12, 31, 36}), frozenset()),
#  (frozenset({41}), frozenset()),
#  (frozenset({42}), frozenset()),
#  (frozenset({7, 49}), frozenset()),
#  (frozenset({7, 37, 45}), frozenset()),
#  (frozenset({0, 46}), frozenset()),
#  (frozenset({47}), frozenset()),
#  (frozenset({16}), frozenset()),
#  (frozenset({15, 49}), frozenset()),
#  (frozenset({40, 43}), frozenset()),
#  (frozenset({21}), frozenset()),
#  (frozenset({1}), frozenset()),
#  (frozenset({36}), frozenset()),
#  (frozenset({7}), frozenset()),
#  (frozenset({23, 24, 40}), frozenset()),
#  (frozenset({16, 32}), frozenset()),
#  (frozenset({24, 43}), frozenset()),
#  (frozenset({7, 15, 49}), frozenset()),
#  (frozenset({37}), frozenset()),
#  (frozenset({4, 9}), frozenset()),
#  (frozenset({7, 45}), frozenset()),
#  (frozenset({9, 13}), frozenset()),
#  (frozenset({7, 11}), frozenset()),
#  (frozenset({5, 22}), frozenset()),
#  (frozenset({9}), frozenset()),
#  (frozenset({5, 31}), frozenset()),
#  (frozenset({23, 42}), frozenset()),
#  (frozenset({2}), frozenset()),
#  (frozenset({44}), frozenset()),
#  (frozenset({15}), frozenset()),
#  (frozenset({11, 37}), frozenset()),
#  (frozenset({12, 48}), frozenset()),
#  (frozenset({41, 43}), frozenset()),
#  (frozenset({23, 41}), frozenset()),
#  (frozenset({40}), frozenset()),
#  (frozenset({23, 24}), frozenset()),
#  (frozenset({11, 45}), frozenset()),
#  (frozenset({12, 31, 36, 48}), frozenset()),
#  (frozenset({11}), frozenset()),
#  (frozenset({4}), frozenset()),
#  (frozenset({38}), frozenset()),
#  (frozenset({31, 36, 48}), frozenset()),
#  (frozenset({7, 11, 37}), frozenset()),
#  (frozenset({7, 37}), frozenset()),
#  (frozenset({24, 41, 43}), frozenset()),
#  (frozenset({12, 36, 48}), frozenset()),
#  (frozenset({14, 22}), frozenset()),
#  (frozenset({0}), frozenset()),
#  (frozenset({24, 40, 41, 43}), frozenset()),
#  (frozenset({14, 44}), frozenset()),
#  (frozenset({17, 29}), frozenset()),
#  (frozenset({33, 42}), frozenset()),
#  (frozenset({0, 2, 46}), frozenset()),
#  (frozenset({23, 40, 41}), frozenset()),
#  (frozenset({23, 24, 41, 43}), frozenset()),
#  (frozenset({25}), frozenset()),
#  (frozenset({26}), frozenset()),
#  (frozenset({39}), frozenset()),
#  (frozenset({1, 19}), frozenset()),
#  (frozenset({24, 40, 43}), frozenset()),
#  (frozenset({12, 31, 48}), frozenset()),
#  (frozenset({7, 11, 45}), frozenset()),
#  (frozenset({23, 24, 43}), frozenset()),
#  (frozenset({46}), frozenset()),
#  (frozenset({0, 2}), frozenset()),
#  (frozenset({23, 41, 43}), frozenset()),
#  (frozenset({6}), frozenset()),
#  (frozenset({3}), frozenset()),
#  (frozenset({28}), frozenset()),
#  (frozenset({9, 45}), frozenset()),
#  (frozenset({20}), frozenset()),
#  (frozenset({23, 24, 40, 41}), frozenset()),
#  (frozenset({37, 45}), frozenset()),
#  (frozenset({34}), frozenset()),
#  (frozenset({36, 48}), frozenset()),
#  (frozenset({40, 41}), frozenset()),
#  (frozenset({24}), frozenset()),
#  (frozenset({32, 45}), frozenset()),
#  (frozenset({18, 35}), frozenset()),
#  (frozenset({16, 32, 45}), frozenset()),
#  (frozenset({22}), frozenset()),
#  (frozenset({23, 24, 40, 41, 43}), frozenset()),
#  (frozenset({43}), frozenset()),
#  (frozenset({49}), frozenset()),
#  (frozenset({23, 24, 40, 43}), frozenset()),
#  (frozenset({5, 14}), frozenset()),
#  (frozenset({32}), frozenset()),
#  (frozenset({13}), frozenset()),
#  (frozenset({14}), frozenset()),
#  (frozenset({24, 40, 41}), frozenset()),
#  (frozenset({7, 11, 37, 45}), frozenset()),
#  (frozenset({23, 24, 41}), frozenset()),
#  (frozenset({10}), frozenset()),
#  (frozenset({23, 33}), frozenset()),
#  (frozenset({23}), frozenset()),
#  (frozenset({19}), frozenset()),
#  (frozenset({12, 31}), frozenset()),
#  (frozenset({29, 47}), frozenset()),
#  (frozenset({40, 41, 43}), frozenset()),
#  (frozenset({3, 18}), frozenset()),
#  (frozenset({11, 37, 45}), frozenset()),
#  (frozenset({12, 36}), frozenset()),
#  (frozenset({23, 40, 43}), frozenset()),
#  (frozenset({5, 42}), frozenset()),
#  (frozenset({31, 36}), frozenset()),
#  (frozenset({7, 15}), frozenset()),
#  (frozenset({17, 29, 47}), frozenset()),
#  (frozenset({31, 48}), frozenset()),
#  (frozenset({17}), frozenset()),
#  (frozenset({35}), frozenset()),
#  (frozenset({18}), frozenset()),
#  (frozenset({31}), frozenset()),
#  (frozenset({23, 40, 41, 43}), frozenset()),
#  (frozenset({24, 40}), frozenset()),
#  (frozenset({3, 35}), frozenset({18})),
#  (frozenset({5}), frozenset({31})),
#  (frozenset({7, 45}), frozenset({11})),
#  (frozenset({23, 24, 41, 43}), frozenset({40})),
#  (frozenset({45}), frozenset({9})),
#  (frozenset({24, 41}), frozenset({40})),
#  (frozenset({46}), frozenset({2})),
#  (frozenset(), frozenset({9})),
#  (frozenset({23, 40, 41}), frozenset({24})),
#  (frozenset({23, 24, 40}), frozenset({41})),
#  (frozenset({41}), frozenset({24})),
#  (frozenset({40}), frozenset({23})),
#  (frozenset({2, 46}), frozenset({0})),
#  (frozenset({40}), frozenset({41})),
#  (frozenset({31, 36, 48}), frozenset({12})),
#  (frozenset({11}), frozenset({37})),
#  (frozenset({40, 43}), frozenset({24})),
#  (frozenset({36}), frozenset({31})),
#  (frozenset({41}), frozenset({23})),
#  (frozenset(), frozenset({22})),
#  (frozenset(), frozenset({36})),
#  (frozenset({7, 37}), frozenset({45})),
#  (frozenset({48}), frozenset({36})),
#  (frozenset(), frozenset({27})),
#  (frozenset({23, 41, 43}), frozenset({24})),
#  (frozenset({47}), frozenset({17})),
#  (frozenset({5}), frozenset({22})),
#  (frozenset({24, 40}), frozenset({23})),
#  (frozenset({35}), frozenset({3})),
#  (frozenset({36, 48}), frozenset({12})),
#  (frozenset({23, 41}), frozenset({43})),
#  (frozenset({7, 37}), frozenset({11})),
#  (frozenset({23, 24}), frozenset({41})),
#  (frozenset({24, 43}), frozenset({23})),
#  (frozenset({23, 24, 43}), frozenset({40})),
#  (frozenset({40, 41, 43}), frozenset({24})),
#  (frozenset({5}), frozenset({42})),
#  (frozenset({23}), frozenset({42})),
#  (frozenset({12, 31, 36}), frozenset({48})),
#  (frozenset({23, 40}), frozenset({41})),
#  (frozenset({40, 41}), frozenset({23})),
#  (frozenset({12}), frozenset({31})),
#  (frozenset({23, 41}), frozenset({40})),
#  (frozenset({15}), frozenset({7})),
#  (frozenset({33}), frozenset({23})),
#  (frozenset(), frozenset({44})),
#  (frozenset({23, 41, 43}), frozenset({40})),
#  (frozenset({40, 41, 43}), frozenset({23})),
#  (frozenset({45}), frozenset({7})),
#  (frozenset({17, 29}), frozenset({47})),
#  (frozenset({7, 11, 45}), frozenset({37})),
#  (frozenset({23}), frozenset({33})),
#  (frozenset({23, 24, 40, 43}), frozenset({41})),
#  (frozenset({23, 24}), frozenset({40})),
#  (frozenset({2}), frozenset({0})),
#  (frozenset({15}), frozenset({49})),
#  (frozenset({3}), frozenset({35})),
#  (frozenset({24}), frozenset({40})),
#  (frozenset({23, 40}), frozenset({43})),
#  (frozenset({35}), frozenset({18})),
#  (frozenset({45}), frozenset({16})),
#  (frozenset({24, 40, 43}), frozenset({23})),
#  (frozenset({31, 48}), frozenset({36})),
#  (frozenset({41}), frozenset({43})),
#  (frozenset({23, 41}), frozenset({24})),
#  (frozenset({23, 24}), frozenset({43})),
#  (frozenset({23, 40, 41}), frozenset({43})),
#  (frozenset({48}), frozenset({31})),
#  (frozenset({7, 37, 45}), frozenset({11})),
#  (frozenset(), frozenset({7})),
#  (frozenset({7, 15}), frozenset({49})),
#  (frozenset({49}), frozenset({7})),
#  (frozenset({23, 24, 41}), frozenset({43})),
#  (frozenset(), frozenset({3})),
#  (frozenset({43}), frozenset({23})),
#  (frozenset({18}), frozenset({35})),
#  (frozenset({24, 41}), frozenset({43})),
#  (frozenset(), frozenset({45})),
#  (frozenset({16}), frozenset({45})),
#  (frozenset({23}), frozenset({43})),
#  (frozenset({43}), frozenset({41})),
#  (frozenset({12, 31}), frozenset({36})),
#  (frozenset({31}), frozenset({48})),
#  (frozenset({18, 35}), frozenset({3})),
#  (frozenset({0, 2}), frozenset({46})),
#  (frozenset({15, 49}), frozenset({7})),
#  (frozenset({16, 45}), frozenset({32})),
#  (frozenset({0, 46}), frozenset({2})),
#  (frozenset(), frozenset({12})),
#  (frozenset({37, 45}), frozenset({7})),
#  (frozenset({14}), frozenset({5})),
#  (frozenset(), frozenset({0})),
#  (frozenset({23, 24, 40}), frozenset({43})),
#  (frozenset({22}), frozenset({5})),
#  (frozenset(), frozenset({14})),
#  (frozenset({44}), frozenset({14})),
#  (frozenset(), frozenset({28})),
#  (frozenset({31}), frozenset({5})),
#  (frozenset({14}), frozenset({22})),
#  (frozenset({24, 40, 43}), frozenset({41})),
#  (frozenset({24}), frozenset({43})),
#  (frozenset({11}), frozenset({45})),
#  (frozenset({29, 47}), frozenset({17})),
#  (frozenset({12, 36}), frozenset({31})),
#  (frozenset({7}), frozenset({37})),
#  (frozenset({11, 37, 45}), frozenset({7})),
#  (frozenset({43}), frozenset({40})),
#  (frozenset({37}), frozenset({45})),
#  (frozenset({23}), frozenset({41})),
#  (frozenset({31}), frozenset({12})),
#  (frozenset({29}), frozenset({17})),
#  (frozenset({42}), frozenset({33})),
#  (frozenset({41, 43}), frozenset({23})),
#  (frozenset({46}), frozenset({0})),
#  (frozenset({9}), frozenset({13})),
#  (frozenset({23, 24, 43}), frozenset({41})),
#  (frozenset({24, 40}), frozenset({41})),
#  (frozenset({40, 41}), frozenset({24})),
#  (frozenset({37}), frozenset({7})),
#  (frozenset({45}), frozenset({37})),
#  (frozenset({12, 36, 48}), frozenset({31})),
#  (frozenset(), frozenset({4})),
#  (frozenset({1}), frozenset({19})),
#  (frozenset({24}), frozenset({41})),
#  (frozenset({14}), frozenset({44})),
#  (frozenset({23, 43}), frozenset({24})),
#  (frozenset({7}), frozenset({49})),
#  (frozenset({43}), frozenset({24})),
#  (frozenset({5}), frozenset({14})),
#  (frozenset({24, 43}), frozenset({41})),
#  (frozenset({36, 48}), frozenset({31})),
#  (frozenset({17}), frozenset({47})),
#  (frozenset({12}), frozenset({36})),
#  (frozenset({41, 43}), frozenset({40})),
#  (frozenset({47}), frozenset({29})),
#  (frozenset({12, 36}), frozenset({48})),
#  (frozenset({31, 48}), frozenset({12})),
#  (frozenset({7}), frozenset({11})),
#  (frozenset({32}), frozenset({45})),
#  (frozenset({19}), frozenset({1})),
#  (frozenset({3}), frozenset({18})),
#  (frozenset(), frozenset({31})),
#  (frozenset({11, 37}), frozenset({45})),
#  (frozenset(), frozenset({41})),
#  (frozenset(), frozenset({42})),
#  (frozenset({11, 45}), frozenset({7})),
#  (frozenset({7}), frozenset({15})),
#  (frozenset({37, 45}), frozenset({11})),
#  (frozenset({28}), frozenset({27})),
#  (frozenset({31, 36}), frozenset({12})),
#  (frozenset({23, 40}), frozenset({24})),
#  (frozenset(), frozenset({19})),
#  (frozenset({11}), frozenset({7})),
#  (frozenset({24, 41, 43}), frozenset({23})),
#  (frozenset({23, 43}), frozenset({40})),
#  (frozenset({12, 31, 48}), frozenset({36})),
#  (frozenset({2}), frozenset({46})),
#  (frozenset({37}), frozenset({11})),
#  (frozenset({17}), frozenset({29})),
#  (frozenset({40}), frozenset({24})),
#  (frozenset({40, 43}), frozenset({41})),
#  (frozenset({11, 37}), frozenset({7})),
#  (frozenset({36}), frozenset({12})),
#  (frozenset({18}), frozenset({3})),
#  (frozenset({41, 43}), frozenset({24})),
#  (frozenset({24, 40, 41}), frozenset({23})),
#  (frozenset({23, 24, 41}), frozenset({40})),
#  (frozenset(), frozenset({35})),
#  (frozenset({16}), frozenset({32})),
#  (frozenset({24, 41, 43}), frozenset({40})),
#  (frozenset({29}), frozenset({47})),
#  (frozenset({7, 11}), frozenset({37})),
#  (frozenset(), frozenset({16})),
#  (frozenset(), frozenset({5})),
#  (frozenset({16, 32}), frozenset({45})),
#  (frozenset({7, 45}), frozenset({37})),
#  (frozenset({23, 40, 41, 43}), frozenset({24})),
#  (frozenset({13}), frozenset({9})),
#  (frozenset({27}), frozenset({28})),
#  (frozenset({42}), frozenset({23})),
#  (frozenset(), frozenset({32})),
#  (frozenset({31, 36}), frozenset({48})),
#  (frozenset({23, 43}), frozenset({41})),
#  (frozenset(), frozenset({23})),
#  (frozenset({32}), frozenset({16})),
#  (frozenset({4}), frozenset({9})),
#  (frozenset({12, 48}), frozenset({36})),
#  (frozenset(), frozenset({33})),
#  (frozenset({0}), frozenset({46})),
#  (frozenset(), frozenset({48})),
#  (frozenset({3, 18}), frozenset({35})),
#  (frozenset({36}), frozenset({48})),
#  (frozenset({17, 47}), frozenset({29})),
#  (frozenset({12, 31}), frozenset({48})),
#  (frozenset({31}), frozenset({36})),
#  (frozenset({24, 41}), frozenset({23})),
#  (frozenset({24}), frozenset({23})),
#  (frozenset({23, 24, 40, 41}), frozenset({43})),
#  (frozenset({23, 40, 43}), frozenset({24})),
#  (frozenset({42}), frozenset({5})),
#  (frozenset({7}), frozenset({45})),
#  (frozenset({23}), frozenset({40})),
#  (frozenset({45}), frozenset({32})),
#  (frozenset({49}), frozenset({15})),
#  (frozenset({7, 49}), frozenset({15})),
#  (frozenset({7, 11, 37}), frozenset({45})),
#  (frozenset({22}), frozenset({14})),
#  (frozenset({24, 40}), frozenset({43})),
#  (frozenset({33}), frozenset({42})),
#  (frozenset({40, 43}), frozenset({23})),
#  (frozenset({24, 43}), frozenset({40})),
#  (frozenset({0}), frozenset({2})),
#  (frozenset({48}), frozenset({12})),
#  (frozenset({23}), frozenset({24})),
#  (frozenset({40}), frozenset({43})),
#  (frozenset({11, 45}), frozenset({37})),
#  (frozenset(), frozenset({1})),
#  (frozenset(), frozenset({2})),
#  (frozenset(), frozenset({15})),
#  (frozenset({45}), frozenset({11})),
#  (frozenset({9}), frozenset({45})),
#  (frozenset({40, 41}), frozenset({43})),
#  (frozenset({7, 11}), frozenset({45})),
#  (frozenset({24, 40, 41}), frozenset({43})),
#  (frozenset({9}), frozenset({4})),
#  (frozenset({12, 48}), frozenset({31})),
#  (frozenset({32, 45}), frozenset({16})),
#  (frozenset({41}), frozenset({40})),
#  (frozenset({12}), frozenset({48})),
#  (frozenset(), frozenset({18})),
#  (frozenset({23, 40, 43}), frozenset({41})),
#  (frozenset(), frozenset({46})),
#  (frozenset({24, 40, 41, 43}), frozenset({23})),
#  (frozenset(), frozenset({47})),
#  (frozenset({45}), frozenset({7, 11})),
#  (frozenset({24, 41}), frozenset({40, 43})),
#  (frozenset({23}), frozenset({40, 43})),
#  (frozenset({7, 11}), frozenset({37, 45})),
#  (frozenset({7, 45}), frozenset({11, 37})),
#  (frozenset({43}), frozenset({23, 24})),
#  (frozenset({7}), frozenset({11, 45})),
#  (frozenset({15}), frozenset({7, 49})),
#  (frozenset({11}), frozenset({7, 45})),
#  (frozenset({23}), frozenset({40, 41})),
#  (frozenset({24}), frozenset({23, 41})),
#  (frozenset({23, 40}), frozenset({24, 43})),
#  (frozenset({12}), frozenset({31, 36})),
#  (frozenset({41}), frozenset({24, 43})),
#  (frozenset({45}), frozenset({11, 37})),
#  (frozenset({18}), frozenset({3, 35})),
#  (frozenset({23, 40, 41}), frozenset({24, 43})),
#  (frozenset({16}), frozenset({32, 45})),
#  (frozenset({24}), frozenset({23, 43})),
#  (frozenset({31}), frozenset({12, 48})),
#  (frozenset({45}), frozenset({16, 32})),
#  (frozenset({41, 43}), frozenset({23, 24})),
#  (frozenset({23, 41}), frozenset({40, 43})),
#  (frozenset({12, 36}), frozenset({31, 48})),
#  (frozenset({7}), frozenset({11, 37})),
#  (frozenset({2}), frozenset({0, 46})),
#  (frozenset({11}), frozenset({7, 37})),
#  (frozenset({37}), frozenset({7, 11})),
#  (frozenset({41}), frozenset({24, 40})),
#  (frozenset({41}), frozenset({23, 43})),
#  (frozenset({45}), frozenset({7, 37})),
#  (frozenset({11, 37}), frozenset({7, 45})),
#  (frozenset({37}), frozenset({11, 45})),
#  (frozenset({24, 40}), frozenset({41, 43})),
#  (frozenset({41}), frozenset({40, 43})),
#  (frozenset({48}), frozenset({12, 36})),
#  (frozenset({37, 45}), frozenset({7, 11})),
#  (frozenset({29}), frozenset({17, 47})),
#  (frozenset({24, 41}), frozenset({23, 43})),
#  (frozenset({31}), frozenset({36, 48})),
#  (frozenset({23, 40}), frozenset({41, 43})),
#  (frozenset({7}), frozenset({37, 45})),
#  (frozenset({40}), frozenset({41, 43})),
#  (frozenset({23, 24}), frozenset({40, 41})),
#  (frozenset({40}), frozenset({23, 24})),
#  (frozenset({23, 24}), frozenset({41, 43})),
#  (frozenset({12}), frozenset({31, 48})),
#  (frozenset({41}), frozenset({23, 24})),
#  (frozenset({23, 43}), frozenset({24, 41})),
#  (frozenset({23, 24, 43}), frozenset({40, 41})),
#  (frozenset({40}), frozenset({23, 43})),
#  (frozenset({48}), frozenset({31, 36})),
#  (frozenset({48}), frozenset({12, 31})),
#  (frozenset({32}), frozenset({16, 45})),
#  (frozenset({43}), frozenset({23, 40})),
#  (frozenset({23}), frozenset({41, 43})),
#  (frozenset({7}), frozenset({15, 49})),
#  (frozenset({24}), frozenset({40, 43})),
#  (frozenset({37}), frozenset({7, 45})),
#  (frozenset({46}), frozenset({0, 2})),
#  (frozenset({23, 24, 40}), frozenset({41, 43})),
#  (frozenset({7, 37}), frozenset({11, 45})),
#  (frozenset({3}), frozenset({18, 35})),
#  (frozenset({41, 43}), frozenset({24, 40})),
#  (frozenset({24}), frozenset({23, 40})),
#  (frozenset({24}), frozenset({40, 41})),
#  (frozenset({23, 41}), frozenset({24, 40})),
#  (frozenset({31, 48}), frozenset({12, 36})),
#  (frozenset({24, 43}), frozenset({40, 41})),
#  (frozenset({23, 41, 43}), frozenset({24, 40})),
#  (frozenset({11}), frozenset({37, 45})),
#  (frozenset({40}), frozenset({23, 41})),
#  (frozenset({11, 45}), frozenset({7, 37})),
#  (frozenset({40, 43}), frozenset({23, 24})),
#  (frozenset({41, 43}), frozenset({23, 40})),
#  (frozenset({24, 40}), frozenset({23, 41})),
#  (frozenset({40, 43}), frozenset({23, 41})),
#  (frozenset({12, 48}), frozenset({31, 36})),
#  (frozenset({40, 41}), frozenset({24, 43})),
#  (frozenset({43}), frozenset({24, 40})),
#  (frozenset({23, 40, 43}), frozenset({24, 41})),
#  (frozenset({43}), frozenset({24, 41})),
#  (frozenset({36, 48}), frozenset({12, 31})),
#  (frozenset({24, 43}), frozenset({23, 41})),
#  (frozenset({12, 31}), frozenset({36, 48})),
#  (frozenset({43}), frozenset({40, 41})),
#  (frozenset({24, 40, 41}), frozenset({23, 43})),
#  (frozenset({24, 40, 43}), frozenset({23, 41})),
#  (frozenset({23}), frozenset({24, 40})),
#  (frozenset({40, 41}), frozenset({23, 43})),
#  (frozenset({40}), frozenset({24, 41})),
#  (frozenset({23}), frozenset({24, 41})),
#  (frozenset({47}), frozenset({17, 29})),
#  (frozenset({23}), frozenset({24, 43})),
#  (frozenset({41}), frozenset({23, 40})),
#  (frozenset({23, 24}), frozenset({40, 43})),
#  (frozenset({49}), frozenset({7, 15})),
#  (frozenset({24, 40}), frozenset({23, 43})),
#  (frozenset({0}), frozenset({2, 46})),
#  (frozenset({23, 24, 41}), frozenset({40, 43})),
#  (frozenset({36}), frozenset({12, 31})),
#  (frozenset({23, 40}), frozenset({24, 41})),
#  (frozenset({40, 41}), frozenset({23, 24})),
#  (frozenset({35}), frozenset({3, 18})),
#  (frozenset({24, 43}), frozenset({23, 40})),
#  (frozenset({23, 43}), frozenset({40, 41})),
#  (frozenset({43}), frozenset({23, 41})),
#  (frozenset({24, 41}), frozenset({23, 40})),
#  (frozenset({12}), frozenset({36, 48})),
#  (frozenset({24}), frozenset({41, 43})),
#  (frozenset({24, 41, 43}), frozenset({23, 40})),
#  (frozenset({40, 41, 43}), frozenset({23, 24})),
#  (frozenset({17}), frozenset({29, 47})),
#  (frozenset({23, 43}), frozenset({24, 40})),
#  (frozenset({31, 36}), frozenset({12, 48})),
#  (frozenset({23, 41}), frozenset({24, 43})),
#  (frozenset({40, 43}), frozenset({24, 41})),
#  (frozenset({40}), frozenset({24, 43})),
#  (frozenset({36}), frozenset({12, 48})),
#  (frozenset({31}), frozenset({12, 36})),
#  (frozenset({36}), frozenset({31, 48})),
#  (frozenset({24}), frozenset({23, 41, 43})),
#  (frozenset({23, 40}), frozenset({24, 41, 43})),
#  (frozenset({23, 24}), frozenset({40, 41, 43})),
#  (frozenset({43}), frozenset({23, 40, 41})),
#  (frozenset({23}), frozenset({24, 40, 43})),
#  (frozenset({40, 41}), frozenset({23, 24, 43})),
#  (frozenset({41}), frozenset({23, 40, 43})),
#  (frozenset({24}), frozenset({40, 41, 43})),
#  (frozenset({40}), frozenset({24, 41, 43})),
#  (frozenset({36}), frozenset({12, 31, 48})),
#  (frozenset({23}), frozenset({24, 40, 41})),
#  (frozenset({41}), frozenset({24, 40, 43})),
#  (frozenset({41}), frozenset({23, 24, 43})),
#  (frozenset({24}), frozenset({23, 40, 43})),
#  (frozenset({40}), frozenset({23, 24, 41})),
#  (frozenset({40, 43}), frozenset({23, 24, 41})),
#  (frozenset({43}), frozenset({23, 24, 40})),
#  (frozenset({41}), frozenset({23, 24, 40})),
#  (frozenset({37}), frozenset({7, 11, 45})),
#  (frozenset({23, 43}), frozenset({24, 40, 41})),
#  (frozenset({41, 43}), frozenset({23, 24, 40})),
#  (frozenset({43}), frozenset({23, 24, 41})),
#  (frozenset({40}), frozenset({23, 24, 43})),
#  (frozenset({24}), frozenset({23, 40, 41})),
#  (frozenset({45}), frozenset({7, 11, 37})),
#  (frozenset({31}), frozenset({12, 36, 48})),
#  (frozenset({23, 41}), frozenset({24, 40, 43})),
#  (frozenset({24, 40}), frozenset({23, 41, 43})),
#  (frozenset({7}), frozenset({11, 37, 45})),
#  (frozenset({43}), frozenset({24, 40, 41})),
#  (frozenset({48}), frozenset({12, 31, 36})),
#  (frozenset({23}), frozenset({40, 41, 43})),
#  (frozenset({24, 43}), frozenset({23, 40, 41})),
#  (frozenset({24, 41}), frozenset({23, 40, 43})),
#  (frozenset({40}), frozenset({23, 41, 43})),
#  (frozenset({11}), frozenset({7, 37, 45})),
#  (frozenset({12}), frozenset({31, 36, 48})),
#  (frozenset({23}), frozenset({24, 41, 43})),
#  (frozenset({23}), frozenset({24, 40, 41, 43})),
#  (frozenset({43}), frozenset({23, 24, 40, 41})),
#  (frozenset({41}), frozenset({23, 24, 40, 43})),
#  (frozenset({24}), frozenset({23, 40, 41, 43})),
#  (frozenset({40}), frozenset({23, 24, 41, 43}))]

# %%
a.liftFilter(32)
# Out:
# [(frozenset({23, 40, 41}), frozenset({24, 43})),
#  (frozenset({23, 24, 43}), frozenset({40, 41})),
#  (frozenset({24, 43}), frozenset({40, 41})),
#  (frozenset({23, 41, 43}), frozenset({24, 40})),
#  (frozenset({40, 41}), frozenset({24, 43})),
#  (frozenset({23, 40, 43}), frozenset({24, 41})),
#  (frozenset({24, 43}), frozenset({23, 41})),
#  (frozenset({24, 40, 41}), frozenset({23, 43})),
#  (frozenset({24, 40, 43}), frozenset({23, 41})),
#  (frozenset({40, 41}), frozenset({23, 43})),
#  (frozenset({23, 43}), frozenset({40, 41})),
#  (frozenset({24, 41, 43}), frozenset({23, 40})),
#  (frozenset({23, 41}), frozenset({24, 43})),
#  (frozenset({23, 40}), frozenset({24, 41, 43})),
#  (frozenset({40, 41}), frozenset({23, 24, 43})),
#  (frozenset({23, 43}), frozenset({24, 40, 41})),
#  (frozenset({23, 41}), frozenset({24, 40, 43})),
#  (frozenset({24, 40}), frozenset({23, 41, 43})),
#  (frozenset({24, 43}), frozenset({23, 40, 41})),
#  (frozenset({24, 41}), frozenset({23, 40, 43}))]
